# %%
from googleapiclient.discovery import build



#api connection
def Api_connect():
    Api_Id="AIzaSyCQ49rcn02aPPs3H26x9kZUxyBI-xDlz2M"

    api_service_name = "youtube"
    api_version = "v3"
    youtube = build(api_service_name,api_version,developerKey=Api_Id)
    return youtube

youtube=Api_connect()

# %%
import pymongo
import psycopg2
import pandas as pd
import mysql.connector
import datetime
import streamlit as st

# %%
channel_name = 'Microsoft'

# %%
channel_response = youtube.channels().list(
    part='snippet,statistics',
    forUsername=channel_name  # Use channel name instead of the ID
).execute()

# %%
if 'items' in channel_response:
    channel_data = channel_response['items'][0]
    channel_id = channel_data['id']
    channel_name = channel_data['snippet']['title']
    channel_type = channel_data['snippet']['description']  # Fix the description retrieval
    channel_views = channel_data['statistics']['viewCount']
    channel_description = channel_data['snippet']['description']
    subscriber_count = channel_data['statistics']['subscriberCount']
    total_video_count = channel_data['statistics']['videoCount']

    print(f"Channel Name: {channel_name}")
    print(f"Channel ID: {channel_id}")
    print(f"Channel Type: {channel_type}")
    print(f"Channel Views: {channel_views}")
    print(f"Channel_Description: {channel_description}")
    print(f"Subscribers: {subscriber_count}")
    print(f"Total Videos: {total_video_count}")

    # Retrieve playlists for the channel
    playlists_response = youtube.playlists().list(
        part='snippet',
        channelId=channel_id,
        maxResults=20  # You can adjust this, if you want more playlists
    ).execute()

    # Check if the response contains items
    if 'items' in playlists_response:
        # Extract playlist IDs
        playlist_ids = [item['id'] for item in playlists_response['items']]

        # Retrieve videos from each playlist
        for playlist_id in playlist_ids:
            playlist_response = youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id,
                maxResults=20  # You can adjust this value to get more videos if needed
            ).execute()

            # Check if the response contains items
            if 'items' in playlist_response:
                video_ids = [item['contentDetails']['videoId'] for item in playlist_response['items']]
                print('Playlist_name')

                # Retrieve video information for each video
                for video_id in video_ids:
                    video_response = youtube.videos().list(
                        part='snippet,statistics',
                        id=video_id
                    ).execute()

                    # Check if the response contains items and is not empty
                    if 'items' in video_response and len(video_response['items']) > 0:
                        video_data = video_response['items'][0]
                        video_title = video_data['snippet']['title']
                        video_description = video_data['snippet']['description']
                        published_date = video_data['snippet']['publishedAt']
                        view_count = video_data['statistics'].get('viewCount', 'N/A')
                        like_count = video_data['statistics'].get('likeCount', 'N/A')
                        dislike_count = video_data['statistics'].get('dislikeCount', 'N/A')
                        favorite_count = video_data['statistics'].get('favoriteCount', 'N/A')
                        comment_count = video_data['statistics'].get('commentCount', 'N/A')
                        duration= video_data['statistics'].get('duration','N/A')
                        thumbnail_url = video_data['snippet']['thumbnails']['default']['url']

                        print(f"Video Title: {video_title}")
                        print(f"Video ID: {video_id}")
                        print(f"video_description: {video_description}")
                        print(f"view_count:{view_count}")
                        print(f"published_date:{published_date}")
                        print(f"Likes: {like_count}")
                        print(f"Dislikes: {dislike_count}")
                        print(f"favorite_count: {favorite_count}")
                        print(f"Comments: {comment_count}")
                        print(f"duration: {duration}")
                        print(f"thumbnail_url: {thumbnail_url}")
                        print()
                    else:
                        print(f"Video with ID {video_id} not found or has no statistics data.")
# Out:
# Channel Name: Microsoft
# Channel ID: UCFtEEv80fQVKkD4h1PF-Xqw
# Channel Type: Our mission is to empower every person and every organization on the planet to achieve more.
#
# Subscribe to Microsoft's official YouTube channel to explore technology’s role in making the world more sustainable, inclusive, and innovative for all.
#
#
# Channel Views: 124143710
# Channel_Description: Our mission is to empower every person and every organization on the planet to achieve more.
#
# Subscribe to Microsoft's official YouTube channel to explore technology’s role in making the world more sustainable, inclusive, and innovative for all.
#
#
# Subscribers: 1330000
# Total Videos: 1184
# Playlist_name
# Video Title: Microsoft holiday 2023 | Make your holiday a masterpiece
# Video ID: KYqu359oY6o
# video_description: The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Audio description: https://youtu.be/HQZ63Ha17PE
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:30932
# published_date:2023-11-17T15:51:05Z
# Likes: 334
# Dislikes: N/A
# favorite_count: 0
# Comments: 39
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/KYqu359oY6o/default.jpg
#
# Video Title: Paulina's holiday memories created with AI in Microsoft Designer
# Video ID: XSlWR-Hn96U
# video_description: For Lunar New Year, Paulina and her grandmother spent an evening wrapping dumplings, a symbol of prosperity.
#
# The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Prompt: an abstract modern art liminal dream holiday new year family scene, surreal art, everyone wearing red clothes, beautiful dumplings, music notes in the air, hong kong
#
# For audio description: https://youtu.be/Xu3Mh5HR4Y4
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2023
# published_date:2023-11-17T15:51:14Z
# Likes: 22
# Dislikes: N/A
# favorite_count: 0
# Comments: 5
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/XSlWR-Hn96U/default.jpg
#
# Video Title: Dario's holiday memories created with AI in Microsoft Designer
# Video ID: 78HQhx8mLus
# video_description: Dario isn’t what you’d call a “holiday person,” but there’s one celebration he can’t forget: the Feast of the Seven Fishes.
#
# The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Prompt: colorful festive, highly detailed gaudy, ornaments and a Santa holding a fish, 1970s classic animation, stop motion, feast of the seven fishes, centered early 3D animation, three dimensional 1980s animation, cute funny, cheesy, feast of the seven fishes, italian
#
# Audio description: https://youtu.be/3rTjT8E1sfY
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1618
# published_date:2023-11-17T15:51:35Z
# Likes: 23
# Dislikes: N/A
# favorite_count: 0
# Comments: 3
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/78HQhx8mLus/default.jpg
#
# Video Title: Tacuma's holiday memories created with AI in Microsoft Designer
# Video ID: hDTbF3MdfHo
# video_description: Tacuma cherishes memories of doing origami, eating food from lacquered boxes, and visiting a Tokyo amusement park with his family on New Year’s.
#
# The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Prompt: abstract art paper art origami diorama, tokyo, amusement park, modern art ukiyo-e style, colorful, ukiyo
#
# Audio description: https://youtu.be/xVzgOntY_1U
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1300
# published_date:2023-11-17T15:51:20Z
# Likes: 21
# Dislikes: N/A
# favorite_count: 0
# Comments: 1
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/hDTbF3MdfHo/default.jpg
#
# Video Title: Silvana's holiday memories created with AI in Microsoft Designer
# Video ID: 0njPQgUCxqM
# video_description: When Silvana wears her grandmother’s great black coat, it’s like taking a walk with her on Christmas.
#
# The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Prompt: felt art patchwork, wide angle landscape scene of a blonde woman wearing a dark wool jacket in center frame looking out over the ocean to christmas land, small angel spirit in the sky, needlepoint, abstract silhouette, expressionist style, colorful holiday
#
# For audio description: https://youtu.be/niVXdiUzdUc
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1691
# published_date:2023-11-17T15:51:39Z
# Likes: 25
# Dislikes: N/A
# favorite_count: 0
# Comments: 1
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/0njPQgUCxqM/default.jpg
#
# Video Title: Nahar's holiday memories created with AI in Microsoft Designer
# Video ID: LkgI6f_i06Y
# video_description: Nahar gathered with her mom, her sisters, and some cats to sing Hanukkah songs, their hair all aglow.
#
# The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Prompt: 4 women with long hair singing around the piano, 2-3 cats on the piano, 3 hanukkah on piano, sufganiot, byzantine japanese woodblock scene, in viennese secession style, gilded, chromatic, whimsical, hanukkah
#
# Audio description: https://youtu.be/_JIGXNK-M7Q
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1452
# published_date:2023-11-17T15:51:28Z
# Likes: 26
# Dislikes: N/A
# favorite_count: 0
# Comments: 2
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/LkgI6f_i06Y/default.jpg
#
# Video Title: José's holiday memories created with AI in Microsoft Designer
# Video ID: ReGjH-CmcBE
# video_description: José’s family built a puppet called “Año Viejo” on New Year’s Eve, a tradition in Ecuador that represents the past year.
#
# The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Prompt: abstract surrealism minimal felt cloth sewn art, 3d animated, colorful, octane render abstract, ecuador, a theatre backdrop new year holiday scene, ecuadorian puppets in foreground, Ecuador Año Viejo holiday celebration, family around a holiday fire outside with ecuadorian puppets capturing the magic of childhood, latin american art, fine art
#
# Audio description: https://youtu.be/sozBDozrIU8
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1539
# published_date:2023-11-17T15:51:41Z
# Likes: 33
# Dislikes: N/A
# favorite_count: 0
# Comments: 1
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/ReGjH-CmcBE/default.jpg
#
# Video Title: Nahar x Maher x Paulina | Make your holiday a masterpiece | AI in Microsoft Designer
# Video ID: g4YmrVt1McQ
# video_description: The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Audio description: https://youtu.be/S7FP9dtsIck
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:3504
# published_date:2023-11-17T15:51:50Z
# Likes: 58
# Dislikes: N/A
# favorite_count: 0
# Comments: 24
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/g4YmrVt1McQ/default.jpg
#
# Video Title: Dario x Tacuma x Silvana | Make your holiday a masterpiece | AI in Microsoft Designer
# Video ID: CgtwBhRS39s
# video_description: The holidays are different for everyone, but they’re all about the unique memories and traditions we create. Whether it’s singing with your cats, eating from bento boxes, or watching the night sky—the holidays are uniquely yours.
#
# We asked people to share their holiday stories—and transmedia artist Ellie Pritts transformed them into prompts, using AI in Microsoft Designer to turn them into masterpieces. They’re all a little different because the people and traditions are all a little different, yet at their heart are the distinct memories that shape and connect us.
#
# No matter how you celebrate, make your holiday a masterpiece — https://microsoft.com/holidays
#
# Audio description: https://youtu.be/eXvJrhBzDus
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1394
# published_date:2023-11-17T15:51:47Z
# Likes: 21
# Dislikes: N/A
# favorite_count: 0
# Comments: 1
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/CgtwBhRS39s/default.jpg
#
# Playlist_name
# Video Title: Full Keynote: Satya Nadella at Microsoft Ignite 2023
# Video ID: FZhbJZEgKQ4
# video_description: Full Keynote: Satya Nadella at Microsoft Ignite 2023
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:419928
# published_date:2023-11-16T04:51:15Z
# Likes: 5814
# Dislikes: N/A
# favorite_count: 0
# Comments: 260
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/FZhbJZEgKQ4/default.jpg
#
# Video Title: AI + Mixed Reality for the Frontline | Copilot in Dynamics 365 Guides
# Video ID: oZOcn8RFLks
# video_description: Copilot in Dynamics 365 Guides transforms the real world into an input for generative AI, providing assistance to frontline workers in industrial settings. Now, workers can interact with Copilot using natural language and gestures to receive the information they need in real-time with speech and holograms. Mixed reality together with AI presents a human-first interface that promises to accelerate real-world processes. Copilot in Guides holds significant potential for businesses seeking greater efficiency and effectiveness in their operations.
#
# Read more about this exciting feature: https://aka.ms/mixedreality
#
# Audio description: https://youtu.be/Oln-0sh1Jmk
#
# #Copilot #mixedreality #HoloLens2 #Dynamics365 #AI #generativeAI
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:191719
# published_date:2023-11-15T17:01:20Z
# Likes: 9014
# Dislikes: N/A
# favorite_count: 0
# Comments: 482
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/oZOcn8RFLks/default.jpg
#
# Video Title: NVIDIA Partnership: Satya Nadella at Microsoft Ignite 2023
# Video ID: QsWtiop4IJA
# video_description: Satya Nadella at Microsoft Ignite 2023 - Microsoft's Satya Nadella talks to NVIDIA's Jensen Huang about their partnership.
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:108032
# published_date:2023-11-16T02:32:38Z
# Likes: 1720
# Dislikes: N/A
# favorite_count: 0
# Comments: 96
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/QsWtiop4IJA/default.jpg
#
# Video Title: Keynote Highlights: Satya Nadella at Microsoft Ignite 2023
# Video ID: QMlUJqxhdoY
# video_description: Satya Nadella Keynote Highlights from Microsoft Ignite 2023
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:17909
# published_date:2023-11-16T04:51:08Z
# Likes: 301
# Dislikes: N/A
# favorite_count: 0
# Comments: 16
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/QMlUJqxhdoY/default.jpg
#
# Video Title: Age of Copilots: Satya Nadella at Microsoft Ignite 2023
# Video ID: S2gn_EoSWac
# video_description: The opening video of Satya Nadella's Microsoft Ignite 2023 keynote.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:9768
# published_date:2023-11-15T17:00:56Z
# Likes: 213
# Dislikes: N/A
# favorite_count: 0
# Comments: 8
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/S2gn_EoSWac/default.jpg
#
# Video Title: Microsoft Copilot: Satya Nadella at Microsoft Ignite 2023
# Video ID: YEfnbXlcU_M
# video_description: Satya Nadella at Microsoft Ignite 2023 - Satya Nadella talks about innovations in Microsoft Copilot
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:50850
# published_date:2023-11-16T02:33:32Z
# Likes: 473
# Dislikes: N/A
# favorite_count: 0
# Comments: 22
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/YEfnbXlcU_M/default.jpg
#
# Video Title: Copilot Studio: Satya Nadella at Microsoft Ignite 2023
# Video ID: _NICbozG0i0
# video_description: At Microsoft Ignite 2023, Satya Nadella announced Copilot Studio.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:16382
# published_date:2023-11-15T17:01:04Z
# Likes: 183
# Dislikes: N/A
# favorite_count: 0
# Comments: 5
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/_NICbozG0i0/default.jpg
#
# Video Title: Microsoft Teams: Satya Nadella at Microsoft Ignite 2023
# Video ID: co6sQQ64yfk
# video_description: Satya Nadella at Microsoft Ignite 2023 - Satya Nadella talks about innoations in Microsoft Teams.
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:4000
# published_date:2023-11-16T02:34:07Z
# Likes: 44
# Dislikes: N/A
# favorite_count: 0
# Comments: 4
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/co6sQQ64yfk/default.jpg
#
# Video Title: Data Innovation: Satya Nadella at Microsoft Ignite 2023
# Video ID: C-Qdsj2iClA
# video_description: Satya Nadella at Microsoft Ignite 2023 - Satya Nadella talks about Microsoft's innovation in Data
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1384
# published_date:2023-11-16T02:33:07Z
# Likes: 15
# Dislikes: N/A
# favorite_count: 0
# Comments: 0
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/C-Qdsj2iClA/default.jpg
#
# Video Title: Microsoft Fabric: Satya Nadella at Microsoft Ignite 2023
# Video ID: zrM36hfzkVE
# video_description: At Microsoft Ignite 2023, Satya Nadella announced Microsoft Fabric, the data platform for the era of AI.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:16065
# published_date:2023-11-15T17:00:41Z
# Likes: 153
# Dislikes: N/A
# favorite_count: 0
# Comments: 8
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/zrM36hfzkVE/default.jpg
#
# Video Title: Closing Video: Satya Nadella at Microsoft Ignite 2023
# Video ID: FbnEGpOQPZw
# video_description: At Microsoft Ignite 2023, Satya Nadella shared the story of Anton Mirhorodchenko and how he has been using Copilot.
#
# Audio Description: https://youtu.be/k3M2bicn8lI
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:7159
# published_date:2023-11-15T17:01:29Z
# Likes: 176
# Dislikes: N/A
# favorite_count: 0
# Comments: 3
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/FbnEGpOQPZw/default.jpg
#
# Video Title: AI Infrastructure: Satya Nadella at Microsoft Ignite 2023
# Video ID: AHSboyXhjyw
# video_description: Satya Nadella at Microsoft Ignite 2023- Satya Nadella talks about Microsoft's innovation in AI Infrastructure
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:4168
# published_date:2023-11-16T02:35:38Z
# Likes: 64
# Dislikes: N/A
# favorite_count: 0
# Comments: 4
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/AHSboyXhjyw/default.jpg
#
# Video Title: Foundation Models and Tooling: Satya Nadella at Microsoft Ignite 2023
# Video ID: tEGXq9apCfI
# video_description: Satya Nadella at Microsoft Ignite 2023 - Satya Nadella talks about Microsoft's innovation in Foundation Models and Tooling.
#
# Sign up today for access to Microsoft Ignite keynotes and sessions: https://msft.it/6006iE6mQ
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:3041
# published_date:2023-11-16T02:36:11Z
# Likes: 55
# Dislikes: N/A
# favorite_count: 0
# Comments: 4
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/tEGXq9apCfI/default.jpg
#
# Playlist_name
# Video Title: Full Event | #MicrosoftEvent September 21, 2023
# Video ID: XYUEQ0SyOyE
# video_description: Enter the new era of AI with Copilot for Microsoft. See event announcements from Bing, Edge, Microsoft 365, Surface and Windows. Hear from Satya Nadella and other leaders from Microsoft about our commitment to providing technology to empower every person and organization on the planet achieve more.
#
# 0:00 - 7:35      Intro with CEO Satya Nadella
# 7:36 - 13:05    Introducing Copilot
# 13:06 - 15:49  Copilot in Windows 11
# 15:50 - 21:13  Windows 11 demo
# 21:14 - 28:35  Edge and Bing demo
# 28:35 - 41:46  Microsoft 365 Copilot
# 41:47 - 45:01  Surface Laptop Go 3
# 45:02 - 47:03  Clipchamp on Surface Laptop Go 3
# 47:04 - 50:56  Surface Laptop Studio 2
# 50:57 - 53:34  Inclusive Touchpad on Surface Laptop Studio 2
# 53:35 - 57:52  Adobe Firefly on Surface Laptop Studio 2
# 57:53 - 58:52  Conclusion
#
# Learn more: https://blogs.microsoft.com/blog/2023/09/21/announcing-microsoft-copilot-your-everyday-ai-companion/
#
# #MicrosoftEvent
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:450702
# published_date:2023-09-21T20:27:47Z
# Likes: 8098
# Dislikes: N/A
# favorite_count: 0
# Comments: 569
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/XYUEQ0SyOyE/default.jpg
#
# Video Title: Microsoft Copilot: Your everyday AI companion
# Video ID: l4B1UflAty8
# video_description: Designed to empower people across work and life, the new era of AI with Copilot from Microsoft is here: https://aka.ms/AAlwlsw
#
# #MicrosoftEvent
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:114113
# published_date:2023-09-21T18:38:35Z
# Likes: 2850
# Dislikes: N/A
# favorite_count: 0
# Comments: 188
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/l4B1UflAty8/default.jpg
#
# Video Title: #MicrosoftEvent in less than 2 minutes | September 21, 2023
# Video ID: PZZI1QXlM80
# video_description: Enter the new era of AI with Copilot for Microsoft. See event announcements from Bing, Edge, Microsoft 365, Surface and Windows. Hear from Satya Nadella and other leaders from Microsoft about our commitment to providing technology to empower every person and organization on the planet achieve more. We're excited to discover what you'll do with these new capabilities.
#
# Watch the full event: https://youtu.be/XYUEQ0SyOyE
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1487110
# published_date:2023-09-21T23:41:47Z
# Likes: 1533
# Dislikes: N/A
# favorite_count: 0
# Comments: 80
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/PZZI1QXlM80/default.jpg
#
# Video Title: Satya Nadella Opening Keynote | #MicrosoftEvent September 21, 2023
# Video ID: g4KViNrpa0I
# video_description: Satya Nadella’s opening to the Microsoft Event on September, 21, 2023.
#
# Watch the full event:  https://youtu.be/XYUEQ0SyOyE
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:13587
# published_date:2023-09-22T22:21:18Z
# Likes: 151
# Dislikes: N/A
# favorite_count: 0
# Comments: 22
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/g4KViNrpa0I/default.jpg
#
# Video Title: Introducing Microsoft 365 Chat
# Video ID: ZtXZV41zQZA
# video_description: Audio Description: https://youtu.be/_ZtRDiSaq_E
#
# Microsoft 365 Chat is the hero experience in Microsoft 365 Copilot. It’s a powerful new AI capability in that goes far beyond simple questions and answers to tame the complexity, eliminate the drudgery, and reclaim time at work. Microsoft 365 Chat combs across your entire universe of data at work—all your emails, meetings, chats, documents, and more, plus the web—to tackle your to-do list in a fraction of the time. It can find whatever you need in your files—even the files you forgot existed. And it can connect the dots across all your content and context at the speed of light.
#
# #Microsoft #Microsoft365
# view_count:394067
# published_date:2023-09-21T14:55:00Z
# Likes: 725
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/ZtXZV41zQZA/default.jpg
#
# Video Title: Meet the new Surface Laptop Studio 2
# Video ID: y7KxKws5Voc
# video_description: Surface Laptop Studio 2 is our most powerful Surface ever built, designed for performance, versatility, and creativity.  With the latest 13th Gen Intel® Core™ i7 processors and NVIDIA GeForce RTX 4050 and 4060 graphics cards, it’s 2x faster than the original. Next-gen AI experiences unlock new ways of working with Copilot in Windows and Windows Studio Effects.
#
# Learn more: https://www.surface.com
#
# https://youtu.be/aJ0ilJUMCzg
#
# #MicrosoftSurface #Surface #SurfaceLaptopStudio2
# view_count:653752
# published_date:2023-09-21T15:01:07Z
# Likes: 14295
# Dislikes: N/A
# favorite_count: 0
# Comments: 964
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/y7KxKws5Voc/default.jpg
#
# Video Title: Copilot in Word | Enhance Your Writing and Design
# Video ID: zuDkY-hRyts
# video_description: Copilot in Word transforms every part of the creative process. Coming soon with Designer integration in Word, you can effortlessly incorporate custom graphics into your document--Copilot uses the context of your content to propose stock visuals in the Chat, and you can upload and customize your own images for a more personal touch.
#
# #Microsoft #Microsoft365
# view_count:42544
# published_date:2023-09-21T15:00:50Z
# Likes: 313
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/zuDkY-hRyts/default.jpg
#
# Video Title: Meet the new Surface Laptop Go 3
# Video ID: IXJPVQws7_M
# video_description: Surface Laptop Go 3 is the perfect everyday laptop with the performance and all-day battery life you need to get it all done. It’s ultra-portable at under 2.5 pounds with a vibrant 12.4” touchscreen. Packed with premium features like fingerprint reader and an incredible typing experience, in four stunning colors.
#
# https://youtu.be/hlVnSOttvQg
#
# Learn more: https://www.surface.com
#
# #MicrosoftSurface #Surface #SurfaceLaptopGo3
#
# Music: "Fabulous" by C.U.T.
# view_count:260039
# published_date:2023-09-21T15:01:15Z
# Likes: 3964
# Dislikes: N/A
# favorite_count: 0
# Comments: 289
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/IXJPVQws7_M/default.jpg
#
# Video Title: Copilot Lab | Learn to Work in a New Way
# Video ID: T2UTxLTwDOQ
# video_description: Introducing Copilot Lab to help everyone learn to work iteratively with AI and get the most out of Microsoft 365 Copilot. With Copilot Lab, you can learn to turn a good prompt into a great one, share your favorite prompts with coworkers, and get inspired as we all learn how to work in a whole new way together.
#
# #Microsoft #Microsoft365
# view_count:20494
# published_date:2023-09-21T15:00:32Z
# Likes: 138
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/T2UTxLTwDOQ/default.jpg
#
# Video Title: Introducing Copilot in Windows 11, new AI tools, and more
# Video ID: 5rEZGSFgZVY
# video_description: The best Windows ever is getting even better, with brand new ways to make the everyday easier.
#
# With nearly 200 new features, the new Windows 11 update is one of our most ambitious yet, bringing the power of Copilot and new AI powered experiences to apps like Paint, Photos, Clipchamp and more right to your Windows PC.
#
# Enjoy smart, seamless ways to be more creative, productive, and connected with answers and results that are personalized for you. Getting things done is now easier than you ever thought possible. And thanks to Windows Backup, making the move to Windows 11 is also easier than ever before.
#
# Feature availability and rollout timing may vary. Learn more at https://aka.ms/AAlwlsw
#
# https://youtu.be/7QvaGDIw4UA
#
# Music: “Rise up let’s go” by Amy McKnight
#
# #MicrosoftWindows #Windows #Windows11 #Microsoft
# view_count:1295859
# published_date:2023-09-21T15:00:58Z
# Likes: 43271
# Dislikes: N/A
# favorite_count: 0
# Comments: 2988
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/5rEZGSFgZVY/default.jpg
#
# Video Title: Microsoft 365 Chat: Your Personal Assistant at Work
# Video ID: 214i-FNKZ_s
# video_description: Microsoft 365 Chat is a powerful new capability in Copilot that goes far beyond simple questions and answers to tame the complexity, eliminate the drudgery, and reclaim time at work. Powered by the Microsoft Graph, Microsoft 365 Chat combs across your entire universe of data at work—all your emails, meetings, chats, documents, and more, plus the web—to tackle your to-do list in a fraction of the time. It has a deep understanding of you, your job, your priorities, and your organization. It’s like having someone attend all your meetings—even the ones you missed. It can find whatever you need in your files—even the files you forgot existed. And it can connect the dots across all your content and context at the speed of light.
#
# #Microsoft #Microsoft365
# view_count:27271
# published_date:2023-09-21T15:00:01Z
# Likes: 373
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/214i-FNKZ_s/default.jpg
#
# Video Title: The new Outlook for Windows is here
# Video ID: Mei3QcQ66Mw
# video_description: The new Outlook for Windows is a free app for Windows users. Easily connect and coordinate your various email accounts and calendars in one place, with a sleek and modern interface. Write clear, concise emails and get intelligent suggestions with built-in AI, and access OneDrive files and Office web apps without a subscription.
#
# Learn more: https://www.microsoft.com/en-us/microsoft-365/outlook/outlook-for-windows?ocid=cmm6a1wkv2n
#
# https://youtu.be/WjaBdM5NRe8
#
# #windows11 #outlook
# view_count:321213
# published_date:2023-09-21T15:05:18Z
# Likes: 5370
# Dislikes: N/A
# favorite_count: 0
# Comments: 559
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/Mei3QcQ66Mw/default.jpg
#
# Video Title: Copilot in Excel | Python Integration
# Video ID: vGI6VLr8L5w
# video_description: Copilot in Excel enables anyone to analyze and visualize data like a data analyst. You can now use Copilot to access advanced analytics and create powerful, professional visualizations, generate forecasts and save time sorting through data with Python in Excel. Quickly add a formula column; highlight key data with a prompt like "make all cells red where the value is under 1000;" filter and sort your data; and ask questions to instantly uncover key insights.
#
# #Microsoft #Microsoft365
# view_count:64070
# published_date:2023-09-21T15:00:56Z
# Likes: 483
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/vGI6VLr8L5w/default.jpg
#
# Video Title: Copilot in Outlook | Keep up with Meetings
# Video ID: NRLskfAG2P4
# video_description: Coming soon to Copilot in Outlook, you can follow a Teams meeting that you’re unable to attend right from Outlook. When the meeting starts, Teams notifies the organizer to record it. When the recording is ready, Copilot notifies you that the meeting recap is ready for viewing, directly in Outlook. You’ll soon be able to use the Copilot Chat in Outlook to ask questions or get a summary without leaving your inbox.
# view_count:26276
# published_date:2023-09-21T15:00:17Z
# Likes: 132
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/NRLskfAG2P4/default.jpg
#
# Playlist_name
# Video Title: Cloud Cultures: Season 1 (trailer)
# Video ID: zzKPpw_UQTk
# video_description: The Cloud Cultures series highlights people from some of the fastest growing cloud markets who are using technology to improve the world around them along with the powerful themes of innovation converged with local customs, values, and ways of living. These stories show firsthand how technology and tradition combine to form cloud cultures.
#
# Learn more: https://datacenters.microsoft.com/
#
# Audio described version: https://youtu.be/WQL1ZclRT4s
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1524
# published_date:2023-10-25T16:00:51Z
# Likes: 41
# Dislikes: N/A
# favorite_count: 0
# Comments: 3
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/zzKPpw_UQTk/default.jpg
#
# Video Title: Creating exceptional customer experiences in Italy | Cloud Cultures
# Video ID: J1R_4691xr0
# video_description: The Cloud Cultures series highlights people from some of the fastest growing cloud markets who are using technology to improve the world around them along with the powerful themes of innovation converged with local customs, values, and ways of living. These stories show firsthand how technology and tradition combine to form cloud cultures. This episode explores Italy.
#
# Learn More: https://datacenters.microsoft.com/
#
# 0:00 – 1:14         Introduction
# 1:15 – 4:03         Corey meets with the co-host | Vicky Piria
# 4:04 – 8:26         Weaving hand-stitched heritage with cutting edge technology | Zegna
# 8:27 – 12:33       Growing their research capabilities using the cloud | CREA
# 12:34 – 16:22     Blending old tradition with modern technology | Lavazza Group
# 16:23 – 19:46     Reflecting on Italy’s cloud culture | Recap
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:216509
# published_date:2023-09-27T01:15:01Z
# Likes: 278
# Dislikes: N/A
# favorite_count: 0
# Comments: 30
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/J1R_4691xr0/default.jpg
#
# Video Title: The pursuit of excellence in the United Kingdom | Cloud Cultures
# Video ID: 3VgdMHn1yhs
# video_description: The Cloud Cultures series highlights people from some of the fastest growing cloud markets who are using technology to improve the world around them along with the powerful themes of innovation converged with local customs, values, and ways of living. These stories show firsthand how technology and tradition combine to form cloud cultures. This episode explores the United Kingdom.
#
# 0:00 – 2:08        Introduction
# 2:09 – 5:04        Data-driven excellence | Rolls Royce Engines
# 5:05 – 8:35        Strengthening financial resilience with the cloud | London Stock Exchange Group
# 8:36 – 11:49      Connecting families through the cloud | vCreate
# 11:50 -14:44      Democratizing data | KX
# 14:45 – 17:05    Recap: Reflecting on the UK’s cloud culture
# 17:06 – 17:23    Next on Cloud Cultures
#
# Learn More: https://datacenters.microsoft.com/
#
# Audio Description: https://youtu.be/ET1aKVOrY7I
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:148545
# published_date:2023-09-05T15:00:02Z
# Likes: 179
# Dislikes: N/A
# favorite_count: 0
# Comments: 12
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/3VgdMHn1yhs/default.jpg
#
# Video Title: Global collaboration in Sweden | Cloud Cultures
# Video ID: pdGCRN0rBOA
# video_description: The Cloud Cultures series highlights people from some of the fastest growing cloud markets who are using technology to improve the world around them along with the powerful themes of innovation converged with local customs, values, and ways of living. These stories show firsthand how technology and tradition combine to form cloud cultures. This episode explores Sweden.
#
# 0:00 – 1:38     Introduction
# 1:39 – 4:57     Empowering retailers with technology | Storekey
# 4:58 – 6:36     How trust fuels innovation | Handelsbanken
# 6:37 – 8:59     Enhancing financial security with AI | Swedbank
# 9:00 – 13:04   A holistic approach to sustainability | Vattenfall
# 13:05 – 15:00 Recap: Reflecting on Sweden’s innovation culture
# 5:01 - 15:22     Next on Cloud Cultures
#
# Learn More: https://datacenters.microsoft.com/
#
# Audio Description: https://youtu.be/F8povPLDFkE
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:136159
# published_date:2023-08-14T14:44:48Z
# Likes: 218
# Dislikes: N/A
# favorite_count: 0
# Comments: 12
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/pdGCRN0rBOA/default.jpg
#
# Video Title: Cloud resilience and innovation lessons from Poland | Cloud Cultures
# Video ID: 8k07pzpYOgo
# video_description: The Cloud Cultures series highlights people from some of the fastest growing cloud markets who are using technology to improve the world around them along with the powerful themes of innovation converged with local customs, values, and ways of living. These stories show firsthand how technology and tradition combine to form cloud cultures. The first stop is Poland.
#
# 0:00 – 2:10        Introduction
# 2:11 – 5:07        Rapid digital transformation in retail| CCC Group
# 5:08 – 9:33        Empowering Polish and Ukrainian women with technology | CYBER Trainees Program
# 9:34 – 12:27      Creating a culture of innovation | Nest Bank
# 12:28 – 16:29    At the Microsoft Datacenter in Poland | Recap
# 16:30-16:50       Next on Cloud Cultures
#
# Learn More: https://datacenters.microsoft.com/
#
# Audio Description: https://youtu.be/Dx8Qzpu0xJo
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:386221
# published_date:2023-06-19T15:00:07Z
# Likes: 5496
# Dislikes: N/A
# favorite_count: 0
# Comments: 392
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/8k07pzpYOgo/default.jpg
#
# Playlist_name
# Video Title: How to stay organized with Microsoft Edge
# Video ID: f2mr_kPypYQ
# video_description: Learn how to stay organized and make the most of your time online with Microsoft Edge. Declutter your browser, locate information quickly, and stay on top of your tasks with built-in features and tools designed to help you stay organized. Use vertical tabs, Collections, tab pins, tab groups, and more to custom-organize your ideas and tasks in a way that's best fit for you. Make the most of your time online and keep your personal, professional, and academic life organized with Microsoft Edge.
#
# For audio description: https://youtu.be/xiE_9eGQS0Y
#
# Learn more ways to stay organized online: https://www.microsoft.com/en-us/edge/learning-center/how-to-stay-organized?form=MA13I2
#
# Explore more ways to elevate your browsing experience: https://www.microsoft.com/en-us/edge/learning-center?form=MA13I2
#
# Try Microsoft Edge today: https://www.microsoft.com/en-us/edge/download?form=MA13I2
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# ...
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2773
# published_date:2023-02-23T18:05:56Z
# Likes: 87
# Dislikes: N/A
# favorite_count: 0
# Comments: 2
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/sJl_pZUQAbc/default.jpg
#
# Playlist_name
# Video Title: The Secret History of Solitaire and Minesweeper #shorts #microsoft #technology
# Video ID: Vt_o9_xhNmc
# video_description: Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:1508171
# published_date:2023-01-12T20:00:13Z
# Likes: 1659
# Dislikes: N/A
# favorite_count: 0
# Comments: 23
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/Vt_o9_xhNmc/default.jpg
#
# Video Title: Imagine having to print your PowerPoints weeks in advance! #shorts #microsoft #powerpoint
# Video ID: motsVthh85M
# video_description: Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2719965
# published_date:2023-01-24T20:00:15Z
# Likes: 707
# Dislikes: N/A
# favorite_count: 0
# Comments: 15
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/motsVthh85M/default.jpg
#
# Video Title: Could you carry a 28lb computer every day? #shorts #microsoft #laptop #surface
# Video ID: tItu3CeE4M8
# video_description: Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:9205541
# published_date:2023-01-30T22:00:32Z
# Likes: 1538
# Dislikes: N/A
# favorite_count: 0
# Comments: 15
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/tItu3CeE4M8/default.jpg
#
# Video Title: Microsoft Flight Simulator Then vs. Now #shorts #flightsimulator #microsoft #gaming
# Video ID: nDjT6zYrbRA
# video_description: Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:5339795
# published_date:2023-02-01T17:00:28Z
# Likes: 3886
# Dislikes: N/A
# favorite_count: 0
# Comments: 31
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/nDjT6zYrbRA/default.jpg
#
# Playlist_name
# Video Title: Inclusive: The Film | Microsoft Inclusive Design
# Video ID: mkggZjUY7SY
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:6836
# published_date:2023-01-30T22:32:09Z
# Likes: 90
# Dislikes: N/A
# favorite_count: 0
# Comments: 3
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/mkggZjUY7SY/default.jpg
#
# Video Title: Inclusive Design Sprint: Team Xbox | Microsoft Inclusive Design
# Video ID: euJ0ThtBvLw
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2119
# published_date:2023-01-30T22:32:06Z
# Likes: 32
# Dislikes: N/A
# favorite_count: 0
# Comments: 4
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/euJ0ThtBvLw/default.jpg
#
# Video Title: An intro to Inclusive Design | Microsoft Inclusive Design
# Video ID: 42RojZSB0Yg
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:8338
# published_date:2023-01-30T22:32:02Z
# Likes: 55
# Dislikes: N/A
# favorite_count: 0
# Comments: 6
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/42RojZSB0Yg/default.jpg
#
# Video Title: How do you achieve focus? | Microsoft Inclusive Design
# Video ID: OpuT6A9eFJA
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2136
# published_date:2023-01-30T22:31:59Z
# Likes: 42
# Dislikes: N/A
# favorite_count: 0
# Comments: 2
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/OpuT6A9eFJA/default.jpg
#
# Video Title: Microsoft Inclusive Design | Subject Matter Expert Series ft. Victor with audio description
# Video ID: eva5b_Ov7uo
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale. aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:3939
# published_date:2016-11-10T22:13:42Z
# Likes: 79
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/eva5b_Ov7uo/default.jpg
#
# Video Title: Microsoft Inclusive Design | Subject Matter Expert Series ft. Haben with audio description
# Video ID: Sl0iV7VyqN0
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale. aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:4939
# published_date:2016-11-10T22:13:29Z
# Likes: 118
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/Sl0iV7VyqN0/default.jpg
#
# Video Title: Microsoft Inclusive Design Subject Matter Expert Series ft. Antoine with audio description
# Video ID: -nGaDdfLXNg
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale. aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:3353
# published_date:2016-11-10T22:13:56Z
# Likes: 66
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/-nGaDdfLXNg/default.jpg
#
# Video Title: Microsoft Inclusive Design: Inclusive Skype Communication with audio description
# Video ID: spqqcJf5e5Q
# video_description: Watch what happens when Skype’s translation tool leverages the power of the written word. What does it mean for a technology to empower connections between the hearing impaired as well as between cultures? aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:7833
# published_date:2016-09-16T00:38:47Z
# Likes: 205
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/spqqcJf5e5Q/default.jpg
#
# Video Title: Microsoft Inclusive Design: Building Inclusive Cities with audio description
# Video ID: Fd7Q-mEKfx0
# video_description: What do physical environments and digital design have in common? Mindfulness of human diversity. See how we can learn from city structures to inspire thoughtful and accessible designs that reach everybody. aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2511
# published_date:2016-09-16T00:34:11Z
# Likes: 57
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/Fd7Q-mEKfx0/default.jpg
#
# Video Title: Microsoft Inclusive Design: Creating Digital Systems with audio description
# Video ID: H9j1qKRaIMw
# video_description: How can we create digital designs that are responsive, and unbiased? Starting with the idea that “one size fits one,” see how creativity evolves into inclusive outcomes. aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2268
# published_date:2016-09-16T00:24:52Z
# Likes: 39
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/H9j1qKRaIMw/default.jpg
#
# Video Title: Microsoft Inclusive Design: Empathy with audio description
# Video ID: ESTTX2u7Xi4
# video_description: Having empathy is critical to the design process. Understanding how that differs from sympathy is even more powerful. Explore how this develops into participatory, insightful design. aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:3489
# published_date:2016-09-16T00:30:18Z
# Likes: 59
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/ESTTX2u7Xi4/default.jpg
#
# Video Title: Microsoft Inclusive Design Subject Matter Expert Series ft. Rosemarie with audio description
# Video ID: LxHRQod1d-4
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale. aka.ms/inclusivetoolkit
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:2819
# published_date:2016-11-10T22:14:14Z
# Likes: 62
# Dislikes: N/A
# favorite_count: 0
# Comments: N/A
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/LxHRQod1d-4/default.jpg
#
# Video Title: Inclusive Design for Cognition | Microsoft Inclusive Design
# Video ID: u0x6DeDZbEg
# video_description: This video is part of a series that works hand-in-hand with Inclusive: A Microsoft Design Toolkit. The intent is to support designers and developers to innovate in a way that puts humans first, on a universal scale.
#
# Subscribe to Microsoft on YouTube here: https://aka.ms/SubscribeToYouTube
#
# Follow us on social:
# LinkedIn: https://www.linkedin.com/company/microsoft/
# Twitter: https://twitter.com/Microsoft
# Facebook: https://www.facebook.com/Microsoft/
# Instagram: https://www.instagram.com/microsoft/
#
# For more about Microsoft, our technology, and our mission, visit https://aka.ms/microsoftstories
# view_count:5994
# published_date:2023-03-02T18:32:19Z
# Likes: 173
# Dislikes: N/A
# favorite_count: 0
# Comments: 14
# duration: N/A
# thumbnail_url: https://i.ytimg.com/vi/u0x6DeDZbEg/default.jpg

# %%
client = pymongo.MongoClient('mongodb+srv://phoorneshmurali:phoorneshih@cluster0.2r8dnjv.mongodb.net/?retryWrites=true&w=majority')
db = client["Youtube_data"]

# %%
def insert_channel_data(channel_data):
    channels_collection = db['channels']
    channels_collection.insert_one(channel_data)

def insert_playlist_data(playlist_data):
    playlists_collection = db['playlists']
    playlists_collection.insert_many(playlist_data)

def insert_video_data(video_data):
    videos_collection = db['videos']
    videos_collection.insert_many(video_data)

# %%
channel_data_to_insert = {
    'channel_id': channel_id,
    'channel_name': channel_name,
    'channel_type': channel_type,
    'channel_views': channel_views,
    'channel_description': channel_description,
    'subscriber_count': subscriber_count,
    'total_video_count': total_video_count
}
insert_channel_data(channel_data_to_insert)

# %%
playlist_data_to_insert = []
for playlist_id in playlist_ids:
    # Fetch playlist details from the YouTube API
    playlist_response = youtube.playlists().list(
        part='snippet',
        id=playlist_id
    ).execute()

    if 'items' in playlist_response and playlist_response['items']:
        playlist_name = playlist_response['items'][0]['snippet']['title']
        playlist_data_to_insert.append({
            'playlist_id': playlist_id,
            'channel_id': channel_id,
            'playlist_name': playlist_name
        })
    else:
        print(f"Playlist with ID {playlist_id} not found.")

insert_playlist_data(playlist_data_to_insert)

# %%
video_data_to_insert = []
for playlist_id in playlist_ids:
    playlist_response = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=20
    ).execute()

    if 'items' in playlist_response:
        video_ids = [item['contentDetails']['videoId'] for item in playlist_response['items']]

        for video_id in video_ids:
            video_response = youtube.videos().list(
                part='snippet,statistics',
                id=video_id
            ).execute()

            if 'items' in video_response and video_response['items']:
                video_data = video_response['items'][0]
                video_name = video_data['snippet']['title']
                video_description = video_data['snippet']['description']
                published_date = video_data['snippet']['publishedAt']
                view_count = video_data['statistics'].get('viewCount', 'N/A')
                like_count = video_data['statistics'].get('likeCount', 'N/A')
                dislike_count = video_data['statistics'].get('dislikeCount', 'N/A')
                favorite_count = video_data['statistics'].get('favoriteCount', 'N/A')
                comment_count = video_data['statistics'].get('commentCount', 'N/A')
                duration = video_data['statistics'].get('duration', 'N/A')
                thumbnail_url = video_data['snippet']['thumbnails']['default']['url']

                video_data_to_insert.append({
                    'video_id': video_id,
                    'playlist_id': playlist_id,
                    'video_name': video_name,
                    'video_description': video_description,
                    'published_date': published_date,
                    'view_count': view_count,
                    'like_count': like_count,
                    'favorite_count': favorite_count,
                    'comment_count': comment_count,
                    'duration':duration,
                    'thumbnail_url':thumbnail_url
                    # Add other fields here as needed
                })
            else:
                print(f"Video with ID {video_id} not found or has no statistics data.")

insert_video_data(video_data_to_insert)

# %%
client.close()

# %%
#convering iso datetimeformat to mysql datetime format
def convert_iso8601_to_mysql(iso_datetime_str):
    try:
        iso_datetime = datetime.datetime.strptime(iso_datetime_str, "%Y-%m-%dT%H:%M:%SZ")
        return iso_datetime.strftime('%Y-%m-%d %H:%M:%S')
    except ValueError as e:
        print(f"Error converting datetime: {e}")
        return None

# %%
#functions to handle non-integer values
def handle_non_integer(value):
    try:
        return int(value)
    except (ValueError, TypeError):
        return None

# %%
#connection to mongoDB
mongo_client = pymongo.MongoClient('mongodb+srv://phoorneshmurali:phoorneshih@cluster0.2r8dnjv.mongodb.net/?retryWrites=true&w=majority')
mongo_db = mongo_client['Youtube_data']
mongo_channels_collection = mongo_db['channels']
mongo_playlists_collection = mongo_db['playlists']
mongo_videos_collection = mongo_db['videos']

# %%
mysql_connection = mysql.connector.connect(
    host='localhost',
    user='root',
    port='3306',
    password='password',
    database='youtube'  
)

# Create MySQL cursor
mysql_cursor = mysql_connection.cursor()

# %%
mysql_cursor = mysql_connection.cursor()

# %%
mysql_cursor.execute('''
    CREATE TABLE IF NOT EXISTS channels (
        channel_id VARCHAR(500),
        channel_name VARCHAR(500),
        channel_type TEXT,
        channel_views BIGINT,
        channel_description TEXT,
        subscriber_count INT,
        total_video_count INT
        
    )
''')
#to insert playlist details

mysql_cursor.execute('''
    CREATE TABLE IF NOT EXISTS playlists (
        playlist_id VARCHAR(500),
        channel_id VARCHAR(500),
        playlist_name VARCHAR(500)
        
    )
''')
#to insert video details
mysql_cursor.execute('''
    CREATE TABLE IF NOT EXISTS videos (
        video_id VARCHAR(500),
        playlist_id VARCHAR(500),
        video_name VARCHAR(500),
        video_description TEXT,
        published_date DATETIME,
        view_count BIGINT,
        like_count INT,
        dislike_count INT,
        favourite_count INT,
        comment_count INT,
        duration INT,
        thumbnail_url TEXT
        
    )
''')

mysql_connection.commit()

try:
    # Insert channel data from MongoDB into MySQL
    channel_data = mongo_channels_collection.find()
    for channel in channel_data:
        channel_id = channel.get('channel_id', None)
        channel_name = channel.get('channel_name', None)
        channel_type = channel.get('channel_type', None)
        channel_views = handle_non_integer(channel.get('channel_views', None))
        channel_description = channel.get('channel_description', None)
        subscriber_count = channel.get('subscriber_count', None)
        total_video_count = channel.get('total_video_count', None)

        if channel_id is not None:
            insert_query = '''
                INSERT INTO channels (channel_id, channel_name, channel_type, channel_views, channel_description, subscriber_count, total_video_count)
                VALUES (%s, %s, %s, %s, %s, %s, %s)
            '''
            mysql_cursor.execute(insert_query, (channel_id, channel_name, channel_type, channel_views, channel_description, subscriber_count, total_video_count))

    # Insert playlist data from MongoDB into MySQL
    playlist_data = mongo_playlists_collection.find()
    for playlist in playlist_data:
        playlist_id = playlist.get('playlist_id', None)
        channel_id = playlist.get('channel_id', None)
        playlist_name = playlist.get('playlist_name', None)
        if playlist_id is not None:
            insert_query = '''
                INSERT INTO playlists (playlist_id, channel_id, playlist_name)
                VALUES (%s, %s, %s)
            '''
            mysql_cursor.execute(insert_query, (playlist_id, channel_id, playlist_name))

    # Insert video data from MongoDB into MySQL
    video_data = mongo_videos_collection.find()
    for video in video_data:
        video_id = video.get('video_id', None)
        playlist_id = video.get('playlist_id', None)
        video_name = video.get('video_name', None)
        video_description = video.get('video_description', None)
        published_date_iso8601 = video.get('published_date', None)
        view_count = handle_non_integer(video.get('view_count', None))
        like_count = handle_non_integer(video.get('like_count', None))
        dislike_count = handle_non_integer(video.get('dislike_count', None))
        favourite_count = handle_non_integer(video.get('favourite_count', None))
        comment_count = handle_non_integer(video.get('comment_count', None))
        duration = handle_non_integer(video.get('duration', None))
        thumbnail_url = video.get('thumbnail_url', None)

        if video_id is not None:
            # Converting ISO 8601 datetime to MySQL datetime format
            published_date_mysql = convert_iso8601_to_mysql(published_date_iso8601)

            insert_query = '''
                INSERT INTO videos (video_id, playlist_id, video_name, video_description, published_date, view_count, like_count, dislike_count, favourite_count, comment_count, duration, thumbnail_url)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            '''
            mysql_cursor.execute(insert_query, (video_id, playlist_id, video_name, video_description, published_date_mysql, view_count, like_count, dislike_count, favourite_count, comment_count, duration, thumbnail_url))

    # Commit changes and close MySQL cursor and connection
    mysql_connection.commit()

except Exception as e:
    # Handle exceptions here (e.g., log the error, roll back the transaction)
    print(f"Error: {str(e)}")
    mysql_connection.rollback()

    # Commit changes and close MySQL cursor and connection
    mysql_connection.commit()

# %%
#connecting to mySql
def connect_to_mysql():
    db_connection = mysql.connector.connect(
        host='localhost',
        user='root',
        port='3306',
        password='password',
        database='youtube'
    )

# %%
def execute_query(query):
    try:
        # Connect to MySQL
        with mysql.connector.connect(
            host='localhost',
            user='root',
            password='password',
            database='youtube'
        ) as db_connection:
            # Create a cursor
            with db_connection.cursor() as cursor:
                # Execute the query
                cursor.execute(query)

                # Fetch all the results
                result = cursor.fetchall()

                # Create a DataFrame
                columns = [desc[0] for desc in cursor.description]
                result_df = pd.DataFrame(result, columns=columns)

        return result_df

    except Exception as e:
        print(f"Error: {str(e)}")

# %%
# Define Streamlit app
def main():
    st.title("YouTube Data Analysis")

    # Query buttons
    query1_button = st.button("Query 1: Names of Videos and Their Corresponding Channels")
    query2_button = st.button("Query 2: Channels with Most Videos")
    query3_button = st.button("Query 3: Top 10 Most Viewed Videos")
    query4_button = st.button("Query 4: Comments on Videos")
    query5_button = st.button("Query 5: Videos with Most Likes")
    query6_button = st.button("Query 6: Total Likes and Dislikes for Videos")
    query7_button = st.button("Query 7: Total Views for Channels")
    query8_button = st.button("Query 8: Channels Publishing in 2022")
    query9_button = st.button("Query 9: Average Video Duration by Channel")
    query10_button = st.button("Query 10: Videos with Most Comments")

    if query1_button:
        query1 = """
        SELECT video_name, channel_name FROM combined_data;
        """
        result1 = execute_query(query1)
        st.header("Query 1: Names of Videos and Their Corresponding Channels")
        st.dataframe(result1)

    if query2_button:
        query2 = """
        SELECT channel_name, MAX(total_video_count) AS max_video_count
        FROM channels
        GROUP BY channel_name
        ORDER BY max_video_count DESC;
        """
        result2 = execute_query(query2)
        st.header("Query 2: Channels with Most Videos")
        st.dataframe(result2)

    if query3_button:
        query3 = """
        SELECT channel_name, video_name, MAX(view_count) AS max_view_count
        FROM combined_data
        GROUP BY channel_name, video_name
        ORDER BY max_view_count DESC
        LIMIT 10;
        """
        result3 = execute_query(query3)
        st.header("Query 3: Top 10 Most Viewed Videos")
        st.dataframe(result3)

    if query4_button:
        query4 = """
        SELECT video_name, like_count, dislike_count FROM combined_data;
        """
        result4 = execute_query(query4)
        st.header("Query 4: Comments on Videos")
        st.dataframe(result4)

    if query5_button:
        query5 = """
        SELECT channel_name, video_name, MAX(like_count) AS max_like_count
        FROM combined_data
        GROUP BY channel_name, video_name
        ORDER BY max_like_count DESC;
        """
        result5 = execute_query(query5)
        st.header("Query 5: Videos with Most Likes")
        st.dataframe(result5)

    if query6_button:
        query6 = """
        SELECT video_name, SUM(like_count) AS total_likes, SUM(dislike_count) AS total_dislikes
        FROM combined_data
        GROUP BY video_name;
        """
        result6 = execute_query(query6)
        st.header("Query 6: Total Likes and Dislikes for Videos")
        st.dataframe(result6)

    if query7_button:
        query7 = """
        SELECT channel_name, SUM(channel_views) AS total_views
        FROM channels
        GROUP BY channel_name;
        """
        result7 = execute_query(query7)
        st.header("Query 7: Total Views for Channels")
        st.dataframe(result7)

    if query8_button:
        query8 = """
        SELECT DISTINCT channel_name
        FROM combined_data
        WHERE YEAR(published_date) = 2022;
        """
        result8 = execute_query(query8)
        st.header("Query 8: Channels Publishing in 2022")
        st.dataframe(result8)

    if query9_button:
        query9 = """
        SELECT channel_name, AVG(duration) AS avg_duration
        FROM combined_data
        GROUP BY channel_name;
        """
        result9 = execute_query(query9)
        st.header("Query 9: Average Video Duration by Channel")
        st.dataframe(result9)

    if query10_button:
        query10 = """
        SELECT channel_name, video_name, MAX(comment_count) AS max_comment_count
        FROM combined_data
        GROUP BY channel_name, video_name
        ORDER BY max_comment_count DESC;
        """
        result10 = execute_query(query10)
        st.header("Query 10: Videos with Most Comments")
        st.dataframe(result10)

if __name__ == "__main__":
    main()
